# %%
"""
Script to process track data from a CSV file, interact with the Spotify API to fetch detailed information about tracks, albums, and artists, 
and insert or update this data into a SQL database. 

This script performs the following steps:
1. Initialize logging and the Spotify API client, connect to the database.
2. Read and process the master CSV file containing listening history data.
3. Fetch new tracks and their corresponding audio features, albums, and artists from Spotify.
4. Insert new records into the relevant database tables while checking for duplicates.

This script is designed to handle batch processing of tracks to efficiently manage API calls and database operations.
It may fail due to the unpredictability of Spotify's rate limiting, but will eventually be able to be restarted.
"""

from utils.logging_config import setup_logger, finalize_logger
from utils.file_utils import read_and_process_track_csv, get_batch_track_uris
from utils.spotify_utils import MaxRetriesExceededException, get_spotify_client, fetch_batch_tracks, fetch_audio_features, fetch_album, fetch_artist
from utils.db_utils import initialize_db, check_new_tracks_and_artists, insert_track_artist, insert_new_track, insert_album, insert_artist, update_audio_features, music_listening_history_table, tracks_table, track_artists_table, artists_table, artist_genre_table, albums_table, track_mapping_table, tracks_consolidated_table
from sqlalchemy import select, and_
from datetime import datetime
import logging

# %%
def process_batch(sp, conn, start_index, batch_track_uris, tracks_table, track_artists_table, artists_table, artist_genre_table, albums_table, logger):
    """
    Process a batch of track URIs, checking for new tracks and their respective artists and albums.
    Insert data into respective tables if not already present.

    Args:
        sp (spotipy.Spotify): Spotify client instance.
        conn (Connection): SQLAlchemy connection object.
        start_index (int): The track number in the file to start processing at.
        batch_track_uris (list): List of track URIs to be processed.
        tracks_table (Table): SQLAlchemy Table object for the tracks table.
        track_artists_table (Table): SQLAlchemy Table object for the track_artists table.
        artists_table (Table): SQLAlchemy Table object for the artists table.
        artist_genre_table (Table): SQLAlchemy Table object for the artist_genre table.
        albums_table (Table): SQLAlchemy Table object for the albums table.

    Returns:
        None
    """

    # Checks if there are new tracks or new track artists in the current batch
    batch_has_new_tracks, batch_has_new_track_artists = check_new_tracks_and_artists(conn, batch_track_uris, tracks_table, track_artists_table)
    
    if batch_has_new_tracks or batch_has_new_track_artists:
        logger.info(f"New tracks or track artists found in batch starting at index {start_index}.")
        # Fetches detailed track information from Spotify API for the batch
        batch_tracks = fetch_batch_tracks(logger, sp, batch_track_uris)

        if batch_has_new_track_artists:
            # Inserts new track-artist associations to the database
            handle_new_track_artists(conn, batch_tracks, track_artists_table, logger)

        if batch_has_new_tracks:
            # Fetches audio features from the Spotify API for new tracks in the batch
            af_batch_tracks = fetch_audio_features(logger, sp, batch_track_uris)
            # Inserts new tracks to the database
            handle_new_tracks(sp, conn, batch_tracks, af_batch_tracks, tracks_table, albums_table, artists_table, artist_genre_table, logger)
    else:
        logger.info(f"No new tracks or track artists found in batch starting at index {start_index}.")

def handle_new_track_artists(conn, batch_tracks, track_artists_table, logger):
    """
    Handle the insertion of new track-artist associations for tracks in a batch.

    Args:
        conn (Connection): SQLAlchemy connection object.
        batch_tracks (dict): Dictionary containing track details from Spotify.
        track_artists_table (Table): SQLAlchemy table object for the 'track_artists' table.

    Returns:
        None
    """

    # Iterates over each track in the batch
    for track in batch_tracks['tracks']:
        spotify_track_uri = track['uri']
        spotify_track_id = track['id']
        track_name = track['name']
        track_artists = track['artists']

        # Inserts each new track-artist association into the database
        for track_artist in track_artists:
            insert_track_artist(conn, track_artists_table, spotify_track_uri, spotify_track_id, track_artist, logger)
    conn.commit() 
    logger.info('Track artists committed')

def handle_new_tracks(sp, conn, batch_tracks, af_batch_tracks, tracks_table, albums_table, artists_table, artist_genre_table, logger):
    """
    Process new tracks and their audio features, albums, and artists. Insert them into the database.

    Args:
        sp (spotipy.Spotify): Spotify client instance.
        conn (Connection): SQLAlchemy connection object.
        batch_tracks (dict): Dictionary containing track details from Spotify.
        af_batch_tracks (list): List of audio features for the tracks.
        tracks_table (Table): SQLAlchemy table object for the 'tracks' table.
        albums_table (Table): SQLAlchemy table object for the 'albums' table.
        artists_table (Table): SQLAlchemy table object for the 'artists' table.
        artist_genre_table (Table): SQLAlchemy table object for the 'artist_genre' table.

    Returns:
        None
    """
    try:
        # Loops over each track and its audio features
        for track, audio_features in zip(batch_tracks['tracks'], af_batch_tracks):
            if track is None:
                logger.warning("Skipping track due to missing data")
                continue

            # Checks if the track is already in the tracks table
            if not conn.execute(select(tracks_table).where(tracks_table.c.spotify_track_uri == track['uri'])).scalar():
                insert_new_track(conn, tracks_table, track, logger)

            # Logs if audio features are missing, otherwise inserts/updates them
            if audio_features is None:
                logger.warning(f"Skipping audio feature due to missing data for track: {track.get('id')} {track.get('name', 'Unknown')}")
            else:
                update_audio_features(conn, tracks_table, audio_features)
                logger.info(f"Updated audio features for {track.get('id')} {track.get('name')}")

            # Inserts each new album and artist into the database
            handle_album(sp, conn, track['album'], albums_table, logger)
            handle_artists(sp, conn, track['artists'], artists_table, artist_genre_table, logger)

        # Commits the transaction only after all operations are complete
        conn.commit() 
        logger.info('Tracks, albums, artists, and audio features committed')
        
    except Exception as e:
        logger.error(f"Transaction failed for batch starting at index {start_index}. Error: {e}")
        raise

def handle_album(sp, conn, album, albums_table, logger):
    """
    Handle the insertion of a new album into the 'albums' table.

    Args:
        sp (spotipy.Spotify): Spotify client instance.
        conn (Connection): SQLAlchemy connection object.
        album (dict): Dictionary containing album details from Spotify.
        albums_table (Table): SQLAlchemy table object for the 'albums' table.

    Returns:
        None
    """

    # Checks if the album is already in the albums table
    if not conn.execute(select(albums_table).where(and_(albums_table.c.spotify_artist_id == album['artists'][0]['id'], albums_table.c.spotify_album_id == album['id']))).scalar():
        insert_album(conn, albums_table, fetch_album(logger, sp, album['uri']), logger)

def handle_artists(sp, conn, track_artists, artists_table, artist_genre_table, logger):
    """
    Handle the insertion of new artists into the artists and artist_genre tables.

    Args:
        sp (spotipy.Spotify): Spotify client instance.
        conn (Connection): SQLAlchemy connection object.
        track_artists (list): List of artists associated with a track.
        artists_table (Table): SQLAlchemy table object for the 'artists' table.
        artist_genre_table (Table): SQLAlchemy table object for the 'artist_genre' table.

    Returns:
        None
    """
    
    for track_artist in track_artists:
        # Checks if the artist is already in the artists table
        if not conn.execute(select(artists_table).where(artists_table.c.spotify_artist_id == track_artist['id'])).scalar():
            insert_artist(conn, artists_table, artist_genre_table, fetch_artist(logger, sp, track_artist['uri']), logger)

# %%
def main():
    """
    Main function to handle the batch processing of tracks from CSV data, make relevant Spotify
    API calls and insert the returned data into the appropriate database tables
    """

    logger = setup_logger('spotify_api_batch_logger', 'spotify_api_batch.log', log_level='INFO')
    db, metadata = initialize_db()
    sp = get_spotify_client()
    track_df = read_and_process_track_csv()
    
    # Constants for batch processing
    start_index = int(input("Enter the starting index. If this is the first run, enter 0: "))
    batch_size = 50
    
    try:
        # Processes batches of tracks until all are handled
        while start_index < len(track_df):
            # Retrieves a batch of track URIs from the DataFrame
            batch_track_uris = get_batch_track_uris(track_df, start_index, batch_size)

            with db.connect() as conn:
                # Makes Spotify API calls on batch tracks, insert new data into database
                process_batch(sp, conn, start_index, batch_track_uris, tracks_table, track_artists_table, artists_table, artist_genre_table, albums_table, logger)

                start_index += batch_size

    except MaxRetriesExceededException as e:
        # This will stop the script completely on max retries.
        logger.error(f"Max retries exceeded: {e}")
        raise
    
    except Exception as e:
        logger.error(f"An error occurred. Batch start index is {start_index}: {e}") 

    finally:
        # Ensure the logger is properly closed regardless of outcome
        finalize_logger(logger)

if __name__ == "__main__":
    main()
# Out:
# 2024-10-11 13:38:28,151 - INFO - ======== Start of Run: 2024-10-11 13:38:28.151626 =======
# Enter the starting index. If this is the first run, enter 0:  39550
# 2024-10-11 13:38:33,615 - INFO - New tracks or track artists found in batch starting at index 39550.
# 2024-10-11 13:38:33,615 - INFO - About to make a tracks call
# 2024-10-11 13:38:39,029 - INFO - About to make an audio features call
# 2024-10-11 13:38:44,155 - INFO - Track: 6kfokZl9BuXPOtvNMsclV2 Don't Go added
# 2024-10-11 13:38:44,163 - INFO - Updated audio features for 6kfokZl9BuXPOtvNMsclV2 Don't Go
# 2024-10-11 13:38:44,171 - INFO - Track: 6kgIu3JMVjoTNuZMMHC1O0 John the Fisherman added
# 2024-10-11 13:38:44,187 - INFO - Updated audio features for 6kgIu3JMVjoTNuZMMHC1O0 John the Fisherman
# 2024-10-11 13:38:44,195 - INFO - Track: 6kh2E3waH1VtyysQBgCvxa Float added
# 2024-10-11 13:38:44,203 - INFO - Updated audio features for 6kh2E3waH1VtyysQBgCvxa Float
# 2024-10-11 13:38:44,211 - INFO - Track: 6khgeAejkFkfdsfauTp6dJ The Willing Well I: Fuel for the Feeding End added
# 2024-10-11 13:38:44,219 - INFO - Updated audio features for 6khgeAejkFkfdsfauTp6dJ The Willing Well I: Fuel for the Feeding End
# 2024-10-11 13:38:44,235 - INFO - Track: 6kiIVIbmwEw6JvIZc7UG0E Perfect Time added
# 2024-10-11 13:38:44,235 - INFO - Updated audio features for 6kiIVIbmwEw6JvIZc7UG0E Perfect Time
# 2024-10-11 13:38:44,251 - INFO - Track: 6kjEZNcvRZZW1h4E6x8HJD Aftermath added
# 2024-10-11 13:38:44,260 - INFO - Updated audio features for 6kjEZNcvRZZW1h4E6x8HJD Aftermath
# 2024-10-11 13:38:44,268 - INFO - Track: 6kkKmXPMYBXUkzH381H7wq Good Morning (feat. Pusha T, Swizz Beatz & Killer Mike) added
# 2024-10-11 13:38:44,276 - INFO - Updated audio features for 6kkKmXPMYBXUkzH381H7wq Good Morning (feat. Pusha T, Swizz Beatz & Killer Mike)
# 2024-10-11 13:38:44,292 - INFO - Track: 6kl1qtQXQsFiIWRBK24Cfp RAF (feat. A$AP Rocky, Playboi Carti, Quavo, Lil Uzi Vert & Frank Ocean) added
# 2024-10-11 13:38:44,300 - INFO - Updated audio features for 6kl1qtQXQsFiIWRBK24Cfp RAF (feat. A$AP Rocky, Playboi Carti, Quavo, Lil Uzi Vert & Frank Ocean)
# 2024-10-11 13:38:44,300 - INFO - About to make an album call
# 2024-10-11 13:38:49,393 - INFO - Album: RAF (feat. A$AP Rocky, Playboi Carti, Quavo, Lil Uzi Vert & Frank Ocean) added
# 2024-10-11 13:38:49,409 - INFO - Track: 6klJ97yVlWKmqB1hEJgXSm The Living Bubba added
# 2024-10-11 13:38:49,417 - INFO - Updated audio features for 6klJ97yVlWKmqB1hEJgXSm The Living Bubba
# 2024-10-11 13:38:49,425 - INFO - Track: 6klcfLeLG0gv64vGjs05FL Momma I'm So Sorry added
# 2024-10-11 13:38:49,433 - INFO - Updated audio features for 6klcfLeLG0gv64vGjs05FL Momma I'm So Sorry
# 2024-10-11 13:38:49,441 - INFO - Track: 6klzQUk22YkppyrWlf5NIt Skin And Bones - Live at the Pantages Theatre, Los Angeles, CA - August 2006 added
# 2024-10-11 13:38:49,457 - INFO - Updated audio features for 6klzQUk22YkppyrWlf5NIt Skin And Bones - Live at the Pantages Theatre, Los Angeles, CA - August 2006
# 2024-10-11 13:38:49,457 - INFO - About to make an album call
# 2024-10-11 13:38:54,700 - INFO - Album: Skin And Bones (Live) added
# 2024-10-11 13:38:54,708 - INFO - Track: 6km1CttFobu2QezdtOJ3qm I Think I Can Fly (feat. Snoop Dogg) added
# 2024-10-11 13:38:54,716 - INFO - Updated audio features for 6km1CttFobu2QezdtOJ3qm I Think I Can Fly (feat. Snoop Dogg)
# 2024-10-11 13:38:54,716 - INFO - About to make an album call
# 2024-10-11 13:38:59,919 - INFO - Album: Role Model added
# 2024-10-11 13:38:59,927 - INFO - Track: 6kmFSxoIKXROHMgkqqLQl9 Remenissions added
# 2024-10-11 13:38:59,935 - INFO - Updated audio features for 6kmFSxoIKXROHMgkqqLQl9 Remenissions
# 2024-10-11 13:38:59,943 - INFO - Track: 6kmSmIbfnGTaGCgwFW7umS Tales added
# 2024-10-11 13:38:59,951 - INFO - Updated audio features for 6kmSmIbfnGTaGCgwFW7umS Tales
# 2024-10-11 13:38:59,967 - INFO - Track: 6kmuRUZVbb072TGNVy5mci Inspiration on Demand added
# 2024-10-11 13:38:59,975 - INFO - Updated audio features for 6kmuRUZVbb072TGNVy5mci Inspiration on Demand
# 2024-10-11 13:38:59,991 - INFO - Track: 6koLlbLduMpML3FaQFDFru OOGARAGE added
# 2024-10-11 13:38:59,991 - INFO - Updated audio features for 6koLlbLduMpML3FaQFDFru OOGARAGE
# 2024-10-11 13:38:59,999 - INFO - About to make an album call
# 2024-10-11 13:39:05,068 - INFO - Album: OOGARAGE / SPORTS added
# 2024-10-11 13:39:05,076 - INFO - Track: 6koWevx9MqN6efQ6qreIbm A Walk added
# 2024-10-11 13:39:05,084 - INFO - Updated audio features for 6koWevx9MqN6efQ6qreIbm A Walk
# 2024-10-11 13:39:05,093 - INFO - Track: 6kpSvAxGAJ0oBZwKnDosY6 Tranquil Moonlit Melodies added
# 2024-10-11 13:39:05,101 - INFO - Updated audio features for 6kpSvAxGAJ0oBZwKnDosY6 Tranquil Moonlit Melodies
# 2024-10-11 13:39:05,117 - INFO - Track: 6kppljCCV2eQiBZPBiCP7g Northern Lights - Japanese Wallpaper Remix added
# 2024-10-11 13:39:05,133 - INFO - Updated audio features for 6kppljCCV2eQiBZPBiCP7g Northern Lights - Japanese Wallpaper Remix
# 2024-10-11 13:39:05,133 - INFO - About to make an album call
# 2024-10-11 13:39:10,209 - INFO - Album: Northern Lights (Japanese Wallpaper Remix) added
# 2024-10-11 13:39:10,209 - INFO - About to make an artist call
# 2024-10-11 13:39:15,307 - INFO - Artist: 2xUsnfrcs3h2FzdRQvGmGM Japanese Wallpaper added
# 2024-10-11 13:39:15,307 - INFO - 2xUsnfrcs3h2FzdRQvGmGM Japanese Wallpaper genre: australian indie added
# 2024-10-11 13:39:15,307 - INFO - 2xUsnfrcs3h2FzdRQvGmGM Japanese Wallpaper genre: indie dream pop added
# 2024-10-11 13:39:15,323 - INFO - Track: 6kqOWNBbrkAuufJpOC5Xvq Connect The Cuts added
# 2024-10-11 13:39:15,339 - INFO - Updated audio features for 6kqOWNBbrkAuufJpOC5Xvq Connect The Cuts
# 2024-10-11 13:39:15,348 - INFO - Track: 6kqPWdv1pNXp6A2CowGSFA Gang Gang added
# 2024-10-11 13:39:15,356 - INFO - Updated audio features for 6kqPWdv1pNXp6A2CowGSFA Gang Gang
# 2024-10-11 13:39:15,364 - INFO - Track: 6krFVB0KUhlPdXJPUG3N22 Fall Out added
# 2024-10-11 13:39:15,372 - INFO - Updated audio features for 6krFVB0KUhlPdXJPUG3N22 Fall Out
# 2024-10-11 13:39:15,380 - INFO - Track: 6krYS8KtmNAYyb5uTZiYW4 Dawn FM added
# 2024-10-11 13:39:15,388 - INFO - Updated audio features for 6krYS8KtmNAYyb5uTZiYW4 Dawn FM
# 2024-10-11 13:39:15,404 - INFO - Track: 6kuImRoOCCTzOVcPpQEjdU Love, Sex, And Fancy Things added
# 2024-10-11 13:39:15,412 - INFO - Updated audio features for 6kuImRoOCCTzOVcPpQEjdU Love, Sex, And Fancy Things
# 2024-10-11 13:39:15,420 - INFO - Track: 6kucNn22HB0qb2ZPa1BrNl Cold, Cold Feeling added
# 2024-10-11 13:39:15,428 - INFO - Updated audio features for 6kucNn22HB0qb2ZPa1BrNl Cold, Cold Feeling
# 2024-10-11 13:39:15,428 - INFO - About to make an album call
# 2024-10-11 13:39:20,514 - INFO - Album: Ice Pickin' added
# 2024-10-11 13:39:20,514 - INFO - About to make an artist call
# 2024-10-11 13:39:25,591 - INFO - Artist: 1uFixbBAduJkFAeRKznkvW Albert Collins added
# 2024-10-11 13:39:25,591 - INFO - 1uFixbBAduJkFAeRKznkvW Albert Collins genre: acoustic blues added
# 2024-10-11 13:39:25,591 - INFO - 1uFixbBAduJkFAeRKznkvW Albert Collins genre: blues added
# 2024-10-11 13:39:25,591 - INFO - 1uFixbBAduJkFAeRKznkvW Albert Collins genre: blues rock added
# 2024-10-11 13:39:25,591 - INFO - 1uFixbBAduJkFAeRKznkvW Albert Collins genre: electric blues added
# 2024-10-11 13:39:25,599 - INFO - 1uFixbBAduJkFAeRKznkvW Albert Collins genre: modern blues added
# 2024-10-11 13:39:25,599 - INFO - 1uFixbBAduJkFAeRKznkvW Albert Collins genre: texas blues added
# 2024-10-11 13:39:25,599 - INFO - 1uFixbBAduJkFAeRKznkvW Albert Collins genre: traditional blues added
# 2024-10-11 13:39:25,615 - INFO - Track: 6kvptl6S5I66ELPB2RFkjm Hi & Lo added
# 2024-10-11 13:39:25,623 - INFO - Updated audio features for 6kvptl6S5I66ELPB2RFkjm Hi & Lo
# 2024-10-11 13:39:25,631 - INFO - Track: 6kw9vo6kCSMjXNDmYFnzmJ A Labyrinth of Tombs added
# 2024-10-11 13:39:25,647 - INFO - Updated audio features for 6kw9vo6kCSMjXNDmYFnzmJ A Labyrinth of Tombs
# 2024-10-11 13:39:25,655 - INFO - Track: 6kwYZvnZHywcmE551flqcy Blood Of The Rose added
# 2024-10-11 13:39:25,671 - INFO - Updated audio features for 6kwYZvnZHywcmE551flqcy Blood Of The Rose
# 2024-10-11 13:39:25,679 - INFO - Track: 6kwxmpeEsfsXAUeWfNTciu Meow! Meow! Space Tiger added
# 2024-10-11 13:39:25,688 - INFO - Updated audio features for 6kwxmpeEsfsXAUeWfNTciu Meow! Meow! Space Tiger
# 2024-10-11 13:39:25,696 - INFO - Track: 6kxo2n2WY48fAhLuiwYOAb Sere - Remix added
# 2024-10-11 13:39:25,704 - INFO - Updated audio features for 6kxo2n2WY48fAhLuiwYOAb Sere - Remix
# 2024-10-11 13:39:25,710 - INFO - About to make an album call
# 2024-10-11 13:39:30,790 - INFO - Album: Sere (Remix) added
# 2024-10-11 13:39:30,790 - INFO - About to make an artist call
# 2024-10-11 13:39:35,860 - INFO - Artist: 2NtQA3PY9chI8l65ejZLTP SPINALL added
# 2024-10-11 13:39:35,860 - INFO - 2NtQA3PY9chI8l65ejZLTP SPINALL genre: afrobeats added
# 2024-10-11 13:39:35,860 - INFO - 2NtQA3PY9chI8l65ejZLTP SPINALL genre: afropop added
# 2024-10-11 13:39:35,860 - INFO - 2NtQA3PY9chI8l65ejZLTP SPINALL genre: nigerian pop added
# 2024-10-11 13:39:35,876 - INFO - Track: 6ky18aPUPqThPQJ15v38ZC Tight Like That added
# 2024-10-11 13:39:35,892 - INFO - Updated audio features for 6ky18aPUPqThPQJ15v38ZC Tight Like That
# 2024-10-11 13:39:35,908 - INFO - Track: 6kyX65yJtM2lNpw55Pedvm Join Us Beyond added
# 2024-10-11 13:39:35,924 - INFO - Updated audio features for 6kyX65yJtM2lNpw55Pedvm Join Us Beyond
# 2024-10-11 13:39:35,940 - INFO - Track: 6kypj1iZkDOFv72Q1keSUJ Carbon added
# 2024-10-11 13:39:35,957 - INFO - Updated audio features for 6kypj1iZkDOFv72Q1keSUJ Carbon
# 2024-10-11 13:39:35,981 - INFO - Track: 6kzE5NMIHoBIuahOXyAWP7 Lonesome Valley added
# 2024-10-11 13:39:35,997 - INFO - Updated audio features for 6kzE5NMIHoBIuahOXyAWP7 Lonesome Valley
# 2024-10-11 13:39:35,998 - INFO - About to make an album call
# 2024-10-11 13:39:41,097 - INFO - Album: Synesthesiac added
# 2024-10-11 13:39:41,105 - INFO - Track: 6kzi5LTg5uECin8pC34nxV Montezuma added
# 2024-10-11 13:39:41,126 - INFO - Updated audio features for 6kzi5LTg5uECin8pC34nxV Montezuma
# 2024-10-11 13:39:41,129 - INFO - Track: 6l00AVv8DSJDNNPTIDeZnx Nothing To No One added
# 2024-10-11 13:39:41,137 - INFO - Updated audio features for 6l00AVv8DSJDNNPTIDeZnx Nothing To No One
# 2024-10-11 13:39:41,153 - INFO - Track: 6l0FTxWEzwwvKLRqFJABPt Wildwood Weed added
# 2024-10-11 13:39:41,161 - INFO - Updated audio features for 6l0FTxWEzwwvKLRqFJABPt Wildwood Weed
# 2024-10-11 13:39:41,169 - INFO - Track: 6l1IrrYTktYwmLj4y5Jfco LENG added
# 2024-10-11 13:39:41,177 - INFO - Updated audio features for 6l1IrrYTktYwmLj4y5Jfco LENG
# 2024-10-11 13:39:41,185 - INFO - Track: 6l2Q1Jb5c2VycqDEzp5ZlJ Pneumonia added
# 2024-10-11 13:39:41,201 - INFO - Updated audio features for 6l2Q1Jb5c2VycqDEzp5ZlJ Pneumonia
# 2024-10-11 13:39:41,209 - INFO - Track: 6l3A2EWZSOA8LTMmzRCyD3 Dream House added
# 2024-10-11 13:39:41,218 - INFO - Updated audio features for 6l3A2EWZSOA8LTMmzRCyD3 Dream House
# 2024-10-11 13:39:41,226 - INFO - Track: 6l4l6hax8d2df0BDYiVtl4 Remenissions added
# 2024-10-11 13:39:41,233 - INFO - Updated audio features for 6l4l6hax8d2df0BDYiVtl4 Remenissions
# 2024-10-11 13:39:41,250 - INFO - Track: 6l6GKtdtfri8a9rPy3WiBr The Face (Live) - Houston, Tx - House of Blues - 5/25/13 added
# 2024-10-11 13:39:41,258 - INFO - Updated audio features for 6l6GKtdtfri8a9rPy3WiBr The Face (Live) - Houston, Tx - House of Blues - 5/25/13
# 2024-10-11 13:39:41,266 - INFO - Track: 6l7RAW0pgGD1YZdb2Dg9yi PREY FOR ME/3 added
# 2024-10-11 13:39:41,274 - INFO - Updated audio features for 6l7RAW0pgGD1YZdb2Dg9yi PREY FOR ME/3
# 2024-10-11 13:39:41,290 - INFO - Track: 6l7VxGCmqeseT0K0L9tRXh Must Be Seven added
# 2024-10-11 13:39:41,298 - INFO - Updated audio features for 6l7VxGCmqeseT0K0L9tRXh Must Be Seven
# 2024-10-11 13:39:41,314 - INFO - Track: 6l7ZrfDzuHodT5XfcMmBiX Roy Rogers - Remastered 2014 added
# 2024-10-11 13:39:41,322 - INFO - Updated audio features for 6l7ZrfDzuHodT5XfcMmBiX Roy Rogers - Remastered 2014
# 2024-10-11 13:39:41,330 - INFO - Track: 6l7mnrTeO2UQ8cqZjaJne8 Galactic Love added
# 2024-10-11 13:39:41,338 - INFO - Updated audio features for 6l7mnrTeO2UQ8cqZjaJne8 Galactic Love
# 2024-10-11 13:39:41,354 - INFO - Track: 6l8EbYRtQMgKOyc1gcDHF9 Bridge Over Troubled Water added
# 2024-10-11 13:39:41,362 - INFO - Updated audio features for 6l8EbYRtQMgKOyc1gcDHF9 Bridge Over Troubled Water
# 2024-10-11 13:39:41,370 - INFO - Track: 6l91G5h57AW47LDPMuJSST One More Love Song added
# 2024-10-11 13:39:41,378 - INFO - Updated audio features for 6l91G5h57AW47LDPMuJSST One More Love Song
# 2024-10-11 13:39:41,394 - INFO - Track: 6l9JRy8V7YtqlL9jYzuJkL The Employment Pages added
# 2024-10-11 13:39:41,410 - INFO - Updated audio features for 6l9JRy8V7YtqlL9jYzuJkL The Employment Pages
# 2024-10-11 13:39:41,434 - INFO - Track: 6lADnYVodPyfvKhZF2tu8L Waffles added
# 2024-10-11 13:39:41,450 - INFO - Updated audio features for 6lADnYVodPyfvKhZF2tu8L Waffles
# 2024-10-11 13:39:41,450 - INFO - Tracks, albums, artists, and audio features committed
# 2024-10-11 13:39:41,498 - INFO - New tracks or track artists found in batch starting at index 39600.
# 2024-10-11 13:39:41,498 - INFO - About to make a tracks call
# 2024-10-11 13:39:46,704 - INFO - Track artist: track 6lARXdm3Ar2Y2zc6xfUdZP, artist The Disco Biscuits added
# 2024-10-11 13:39:46,704 - INFO - Track artist: track 6lAZ7xfP9su2ZvGk1rRc3R, artist Pavement added
# 2024-10-11 13:39:46,704 - INFO - Track artist: track 6lAl0AUvqBHBKMRj2Hh9LP, artist As Blood Runs Black added
# 2024-10-11 13:39:46,704 - INFO - Track artist: track 6lBW561DxJ4vbWY3R2jl6u, artist Rolling Blackouts Coastal Fever added
# 2024-10-11 13:39:46,712 - INFO - Track artist: track 6lBolQr5n845NeIfmoHy84, artist Greensky Bluegrass added
# 2024-10-11 13:39:46,712 - INFO - Track artist: track 6lCn2IK3UJHf4mCccFwVMZ, artist La Caution added
# 2024-10-11 13:39:46,712 - INFO - Track artist: track 6lCsyybt0LE9Von1Oc1bqm, artist Zach Deputy added
# 2024-10-11 13:39:46,712 - INFO - Track artist: track 6lDOzVSu4u2CbEYIWA832G, artist Rebelution added
# 2024-10-11 13:39:46,712 - INFO - Track artist: track 6lDTR2JakgO4nyaqASdtIT, artist Love Canon added
# 2024-10-11 13:39:46,712 - INFO - Track artist: track 6lEB7MQxKsqBQ7cACUW2tg, artist J Dilla added
# 2024-10-11 13:39:46,721 - INFO - Track artist: track 6lElZD3sV2qXDqURDZiuFZ, artist Better Oblivion Community Center added
# 2024-10-11 13:39:46,721 - INFO - Track artist: track 6lElZD3sV2qXDqURDZiuFZ, artist Conor Oberst added
# 2024-10-11 13:39:46,721 - INFO - Track artist: track 6lElZD3sV2qXDqURDZiuFZ, artist Phoebe Bridgers added
# 2024-10-11 13:39:46,721 - INFO - Track artist: track 6lFDB0BFDRV58qaQDX85jV, artist Lorde added
# 2024-10-11 13:39:46,728 - INFO - Track artist: track 6lIuS0iCRRkHDtmdQiILeq, artist Gorod added
# 2024-10-11 13:39:46,728 - INFO - Track artist: track 6lJ2oxY3HTzo7s3NByyr3n, artist Ingrid Michaelson added
# 2024-10-11 13:39:46,732 - INFO - Track artist: track 6lJJcUjhsp0TJRuzUIPOYO, artist Pantera added
# 2024-10-11 13:39:46,732 - INFO - Track artist: track 6lJrqw2e6YNXZCUsXL1SKn, artist Madvillain added
# 2024-10-11 13:39:46,736 - INFO - Track artist: track 6lJrqw2e6YNXZCUsXL1SKn, artist Madlib added
# 2024-10-11 13:39:46,736 - INFO - Track artist: track 6lJrqw2e6YNXZCUsXL1SKn, artist MF DOOM added
# 2024-10-11 13:39:46,736 - INFO - Track artist: track 6lJrqw2e6YNXZCUsXL1SKn, artist Wildchild added
# 2024-10-11 13:39:46,736 - INFO - Track artist: track 6lKBrNqKmFIsTH6OTJJ6uO, artist Youth Code added
# 2024-10-11 13:39:46,744 - INFO - Track artist: track 6lKCSY7cmiLZ4on094uHJr, artist Einherjer added
# 2024-10-11 13:39:46,744 - INFO - Track artist: track 6lKHwU8AAsvuATOCwq2aH8, artist Jon Hopkins added
# 2024-10-11 13:39:46,744 - INFO - Track artist: track 6lKOsX2JpmCcOf1ja3Xu6g, artist DIESEL added
# 2024-10-11 13:39:46,744 - INFO - Track artist: track 6lKOsX2JpmCcOf1ja3Xu6g, artist CELO added
# 2024-10-11 13:39:46,744 - INFO - Track artist: track 6lKOsX2JpmCcOf1ja3Xu6g, artist Shaquille O'Neal added
# 2024-10-11 13:39:46,752 - INFO - Track artist: track 6lKg9yX7YlTDFnu8qOt5DT, artist Obscura added
# 2024-10-11 13:39:46,752 - INFO - Track artist: track 6lLKrVjoy9IX1MtTI1aWtz, artist Thank You Scientist added
# 2024-10-11 13:39:46,752 - INFO - Track artist: track 6lMDnP05ipiZUwGxWRGb2n, artist HEALTH added
# 2024-10-11 13:39:46,752 - INFO - Track artist: track 6lMDnP05ipiZUwGxWRGb2n, artist NOLIFE added
# 2024-10-11 13:39:46,760 - INFO - Track artist: track 6lNVIxy78O2qyIK5OejfBL, artist Obscura added
# 2024-10-11 13:39:46,760 - INFO - Track artist: track 6lNsBH0sjxcw7dVxBMKMvz, artist Pianos Become The Teeth added
# 2024-10-11 13:39:46,760 - INFO - Track artist: track 6lO89G2Olrp4makCyOXcqO, artist Grey Code added
# 2024-10-11 13:39:46,760 - INFO - Track artist: track 6lOZmlKgOjuHI5jK4eC4kM, artist Unknown Mortal Orchestra added
# 2024-10-11 13:39:46,760 - INFO - Track artist: track 6lP6fPB5XtWzAy03j68rfU, artist Andre Nickatina added
# 2024-10-11 13:39:46,760 - INFO - Track artist: track 6lQ7Hzw4QckwEFbzuYCWHE, artist Lotus added
# 2024-10-11 13:39:46,768 - INFO - Track artist: track 6lQE6LF3MU63Z6VyhPxaV3, artist Hum added
# 2024-10-11 13:39:46,768 - INFO - Track artist: track 6lQPjlK9jPN9oPnSltqDXR, artist Portugal. The Man added
# 2024-10-11 13:39:46,768 - INFO - Track artist: track 6lQVpykjhYEA9LK7hZi5Yx, artist Static-X added
# 2024-10-11 13:39:46,768 - INFO - Track artist: track 6lRvw8k9ef6YIuJlPLesMu, artist Sabaton added
# 2024-10-11 13:39:46,777 - INFO - Track artist: track 6lS2jdGhJvy0M1gDM8spDy, artist Uncle Acid & The Deadbeats added
# 2024-10-11 13:39:46,777 - INFO - Track artist: track 6lSS5pQ7NA0oqC2UU10fFK, artist Ice Nine Kills added
# 2024-10-11 13:39:46,777 - INFO - Track artist: track 6lSnbMJwCnOzTfBPa0smKK, artist Senses Fail added
# 2024-10-11 13:39:46,777 - INFO - Track artist: track 6lTLgWznUomxzmQpkqGPdF, artist Lil Wayne added
# 2024-10-11 13:39:46,785 - INFO - Track artist: track 6lTLgWznUomxzmQpkqGPdF, artist Post Malone added
# 2024-10-11 13:39:46,785 - INFO - Track artist: track 6lUEeF62McRG0g57k2n5tK, artist Devin Townsend added
# 2024-10-11 13:39:46,785 - INFO - Track artist: track 6lUXneXZ9jc3HSMHgd8oqh, artist Al Green added
# 2024-10-11 13:39:46,785 - INFO - Track artist: track 6lUjedsIIKRBdyNMpdBbai, artist WHY? added
# 2024-10-11 13:39:46,793 - INFO - Track artist: track 6lUyyCRoT2wvtGlQQEpk3U, artist Dance With the Dead added
# 2024-10-11 13:39:46,793 - INFO - Track artist: track 6lWFQo5NuR3y8Q6CHIRatA, artist Overkill added
# 2024-10-11 13:39:46,793 - INFO - Track artist: track 6lXECPIIcucEYXgdTe9vZG, artist Sabaton added
# 2024-10-11 13:39:46,793 - INFO - Track artist: track 6lXSdhCJlyM3Tv6PBaFo5V, artist Iron Maiden added
# 2024-10-11 13:39:46,793 - INFO - Track artist: track 6lZJlAPwtaEp8UDUvmiU3e, artist Metallica added
# 2024-10-11 13:39:46,793 - INFO - Track artist: track 6lZadw4xVrq6bfYmPsNaUC, artist The Menzingers added
# 2024-10-11 13:39:46,801 - INFO - Track artist: track 6lZeAGXROog38eHr2ucBN9, artist Grateful Dead added
# 2024-10-11 13:39:46,801 - INFO - Track artist: track 6lZlWE53RRQeccTEYfBuMW, artist The Afghan Whigs added
# 2024-10-11 13:39:46,801 - INFO - Track artist: track 6lZwlaCaFbZh0E0GEqDGEe, artist Of The Trees added
# 2024-10-11 13:39:46,801 - INFO - Track artist: track 6lZwlaCaFbZh0E0GEqDGEe, artist The Originalz added
# 2024-10-11 13:39:46,809 - INFO - Track artist: track 6lat8Yua6HyTEvN812YrJF, artist Dopapod added
# 2024-10-11 13:39:46,809 - INFO - Track artists committed
# 2024-10-11 13:39:46,809 - INFO - About to make an audio features call
# 2024-10-11 13:39:52,049 - INFO - Track: 6lARXdm3Ar2Y2zc6xfUdZP Story of the World added
# 2024-10-11 13:39:52,065 - INFO - Updated audio features for 6lARXdm3Ar2Y2zc6xfUdZP Story of the World
# 2024-10-11 13:39:52,074 - INFO - Track: 6lAZ7xfP9su2ZvGk1rRc3R Range Life added
# 2024-10-11 13:39:52,082 - INFO - Updated audio features for 6lAZ7xfP9su2ZvGk1rRc3R Range Life
# 2024-10-11 13:39:52,093 - INFO - About to make an album call
# 2024-10-11 13:39:57,266 - INFO - Album: Crooked Rain, Crooked Rain: LA's Desert Origins added
# 2024-10-11 13:39:57,274 - INFO - Track: 6lAl0AUvqBHBKMRj2Hh9LP In Dying Days added
# 2024-10-11 13:39:57,282 - INFO - Updated audio features for 6lAl0AUvqBHBKMRj2Hh9LP In Dying Days
# 2024-10-11 13:39:57,282 - INFO - About to make an album call
# 2024-10-11 13:40:02,361 - INFO - Album: Allegiance added
# 2024-10-11 13:40:02,361 - INFO - About to make an artist call
# 2024-10-11 13:40:07,452 - INFO - Artist: 4LjQpQc5NB5G02zqfEIex7 As Blood Runs Black added
# 2024-10-11 13:40:07,456 - INFO - 4LjQpQc5NB5G02zqfEIex7 As Blood Runs Black genre: deathcore added
# 2024-10-11 13:40:07,460 - INFO - 4LjQpQc5NB5G02zqfEIex7 As Blood Runs Black genre: melodic deathcore added
# 2024-10-11 13:40:07,460 - INFO - 4LjQpQc5NB5G02zqfEIex7 As Blood Runs Black genre: melodic metalcore added
# 2024-10-11 13:40:07,460 - INFO - 4LjQpQc5NB5G02zqfEIex7 As Blood Runs Black genre: metalcore added
# 2024-10-11 13:40:07,468 - INFO - Track: 6lBW561DxJ4vbWY3R2jl6u Bellarine added
# 2024-10-11 13:40:07,476 - INFO - Updated audio features for 6lBW561DxJ4vbWY3R2jl6u Bellarine
# 2024-10-11 13:40:07,492 - INFO - Track: 6lBolQr5n845NeIfmoHy84 Worried About the Weather added
# 2024-10-11 13:40:07,500 - INFO - Updated audio features for 6lBolQr5n845NeIfmoHy84 Worried About the Weather
# 2024-10-11 13:40:07,508 - INFO - Track: 6lCn2IK3UJHf4mCccFwVMZ Thé à la menthe (Instrumental) added
# 2024-10-11 13:40:07,516 - INFO - Updated audio features for 6lCn2IK3UJHf4mCccFwVMZ Thé à la menthe (Instrumental)
# 2024-10-11 13:40:07,516 - INFO - About to make an album call
# 2024-10-11 13:40:12,699 - INFO - Album: Peines de Maures / Arc-en-ciel pour daltoniens (Instrumental Version) added
# 2024-10-11 13:40:12,699 - INFO - About to make an artist call
# 2024-10-11 13:40:17,798 - INFO - Artist: 1MBqzcu6aiY7GzP5BfG56T La Caution added
# 2024-10-11 13:40:17,798 - INFO - 1MBqzcu6aiY7GzP5BfG56T La Caution genre: old school rap francais added
# 2024-10-11 13:40:17,814 - INFO - Track: 6lCsyybt0LE9Von1Oc1bqm Paramus added
# 2024-10-11 13:40:17,834 - INFO - Updated audio features for 6lCsyybt0LE9Von1Oc1bqm Paramus
# 2024-10-11 13:40:17,858 - INFO - Track: 6lDOzVSu4u2CbEYIWA832G Attention Span added
# 2024-10-11 13:40:17,871 - INFO - Updated audio features for 6lDOzVSu4u2CbEYIWA832G Attention Span
# 2024-10-11 13:40:17,898 - INFO - Track: 6lDTR2JakgO4nyaqASdtIT Everybody Wants to Rule the World added
# 2024-10-11 13:40:17,919 - INFO - Updated audio features for 6lDTR2JakgO4nyaqASdtIT Everybody Wants to Rule the World
# 2024-10-11 13:40:17,921 - INFO - About to make an album call
# 2024-10-11 13:40:23,011 - INFO - Album: Greatest Hits Vol. 2 added
# 2024-10-11 13:40:23,019 - INFO - Track: 6lEB7MQxKsqBQ7cACUW2tg Dillatronic 02 added
# 2024-10-11 13:40:23,029 - INFO - Updated audio features for 6lEB7MQxKsqBQ7cACUW2tg Dillatronic 02
# 2024-10-11 13:40:23,044 - INFO - Track: 6lElZD3sV2qXDqURDZiuFZ Forest Lawn added
# 2024-10-11 13:40:23,052 - INFO - Updated audio features for 6lElZD3sV2qXDqURDZiuFZ Forest Lawn
# 2024-10-11 13:40:23,064 - INFO - Track: 6lFDB0BFDRV58qaQDX85jV Liability (Reprise) added
# 2024-10-11 13:40:23,077 - INFO - Updated audio features for 6lFDB0BFDRV58qaQDX85jV Liability (Reprise)
# 2024-10-11 13:40:23,085 - INFO - Track: 6lIuS0iCRRkHDtmdQiILeq Eternal Messiah added
# 2024-10-11 13:40:23,093 - INFO - Updated audio features for 6lIuS0iCRRkHDtmdQiILeq Eternal Messiah
# 2024-10-11 13:40:23,101 - INFO - Track: 6lJ2oxY3HTzo7s3NByyr3n Freak Show added
# 2024-10-11 13:40:23,110 - INFO - Updated audio features for 6lJ2oxY3HTzo7s3NByyr3n Freak Show
# 2024-10-11 13:40:23,119 - INFO - Track: 6lJJcUjhsp0TJRuzUIPOYO Primal Concrete Sledge added
# 2024-10-11 13:40:23,128 - INFO - Updated audio features for 6lJJcUjhsp0TJRuzUIPOYO Primal Concrete Sledge
# 2024-10-11 13:40:23,142 - INFO - Track: 6lJrqw2e6YNXZCUsXL1SKn Hardcore Hustle added
# 2024-10-11 13:40:23,148 - INFO - Updated audio features for 6lJrqw2e6YNXZCUsXL1SKn Hardcore Hustle
# 2024-10-11 13:40:23,150 - INFO - About to make an artist call
# 2024-10-11 13:40:28,209 - INFO - Artist: 0tHPntFCJ48YjmDZ8utweA Wildchild added
# 2024-10-11 13:40:28,219 - INFO - Track: 6lKBrNqKmFIsTH6OTJJ6uO Lost at Sea added
# 2024-10-11 13:40:28,232 - INFO - Updated audio features for 6lKBrNqKmFIsTH6OTJJ6uO Lost at Sea
# 2024-10-11 13:40:28,240 - INFO - Track: 6lKCSY7cmiLZ4on094uHJr Slaget Ved Hafrsjord added
# 2024-10-11 13:40:28,254 - INFO - Updated audio features for 6lKCSY7cmiLZ4on094uHJr Slaget Ved Hafrsjord
# 2024-10-11 13:40:28,269 - INFO - Track: 6lKHwU8AAsvuATOCwq2aH8 The Wider Sun added
# 2024-10-11 13:40:28,279 - INFO - Updated audio features for 6lKHwU8AAsvuATOCwq2aH8 The Wider Sun
# 2024-10-11 13:40:28,289 - INFO - Track: 6lKOsX2JpmCcOf1ja3Xu6g WARFARE added
# 2024-10-11 13:40:28,299 - INFO - Updated audio features for 6lKOsX2JpmCcOf1ja3Xu6g WARFARE
# 2024-10-11 13:40:28,299 - INFO - About to make an artist call
# 2024-10-11 13:40:33,387 - INFO - Artist: 0cF121Uo22slYVIvyft0Eh CELO added
# 2024-10-11 13:40:33,404 - INFO - Track: 6lKg9yX7YlTDFnu8qOt5DT A Valediction added
# 2024-10-11 13:40:33,411 - INFO - Updated audio features for 6lKg9yX7YlTDFnu8qOt5DT A Valediction
# 2024-10-11 13:40:33,428 - INFO - Track: 6lLKrVjoy9IX1MtTI1aWtz Carnival added
# 2024-10-11 13:40:33,439 - INFO - Updated audio features for 6lLKrVjoy9IX1MtTI1aWtz Carnival
# 2024-10-11 13:40:33,460 - INFO - Track: 6lMDnP05ipiZUwGxWRGb2n HARD TO BE A GOD added
# 2024-10-11 13:40:33,477 - INFO - Updated audio features for 6lMDnP05ipiZUwGxWRGb2n HARD TO BE A GOD
# 2024-10-11 13:40:33,478 - INFO - About to make an album call
# 2024-10-11 13:40:38,549 - INFO - Album: HARD TO BE A GOD added
# 2024-10-11 13:40:38,558 - INFO - Track: 6lNVIxy78O2qyIK5OejfBL Orbital Elements II added
# 2024-10-11 13:40:38,569 - INFO - Updated audio features for 6lNVIxy78O2qyIK5OejfBL Orbital Elements II
# 2024-10-11 13:40:38,582 - INFO - Track: 6lNsBH0sjxcw7dVxBMKMvz Liquid Courage added
# 2024-10-11 13:40:38,590 - INFO - Updated audio features for 6lNsBH0sjxcw7dVxBMKMvz Liquid Courage
# 2024-10-11 13:40:38,598 - INFO - Track: 6lO89G2Olrp4makCyOXcqO Actress - Mixed added
# 2024-10-11 13:40:38,609 - INFO - Updated audio features for 6lO89G2Olrp4makCyOXcqO Actress - Mixed
# 2024-10-11 13:40:38,609 - INFO - About to make an album call
# 2024-10-11 13:40:43,689 - INFO - Album: Actress (Mixed) added
# 2024-10-11 13:40:43,705 - INFO - Track: 6lOZmlKgOjuHI5jK4eC4kM Jello and Juggernauts added
# 2024-10-11 13:40:43,720 - INFO - Updated audio features for 6lOZmlKgOjuHI5jK4eC4kM Jello and Juggernauts
# 2024-10-11 13:40:43,736 - INFO - Track: 6lP6fPB5XtWzAy03j68rfU Dice Of Life (The Bottle) added
# 2024-10-11 13:40:43,749 - INFO - Updated audio features for 6lP6fPB5XtWzAy03j68rfU Dice Of Life (The Bottle)
# 2024-10-11 13:40:43,749 - INFO - About to make an album call
# 2024-10-11 13:40:48,993 - INFO - Album: Cocaine Inc (Cocaine Raps 1, 2, & 3) added
# 2024-10-11 13:40:49,001 - INFO - Track: 6lQ7Hzw4QckwEFbzuYCWHE Dim Light added
# 2024-10-11 13:40:49,009 - INFO - Updated audio features for 6lQ7Hzw4QckwEFbzuYCWHE Dim Light
# 2024-10-11 13:40:49,018 - INFO - Track: 6lQE6LF3MU63Z6VyhPxaV3 Stars added
# 2024-10-11 13:40:49,028 - INFO - Updated audio features for 6lQE6LF3MU63Z6VyhPxaV3 Stars
# 2024-10-11 13:40:49,033 - INFO - About to make an album call
# 2024-10-11 13:40:54,110 - INFO - Album: You'd Prefer An Astronaut added
# 2024-10-11 13:40:54,110 - INFO - About to make an artist call
# 2024-10-11 13:40:59,182 - INFO - Artist: 6sM2JCBjZprP7JLMTZZSxX Hum added
# 2024-10-11 13:40:59,182 - INFO - 6sM2JCBjZprP7JLMTZZSxX Hum genre: countrygaze added
# 2024-10-11 13:40:59,182 - INFO - 6sM2JCBjZprP7JLMTZZSxX Hum genre: dreamo added
# 2024-10-11 13:40:59,182 - INFO - 6sM2JCBjZprP7JLMTZZSxX Hum genre: grungegaze added
# 2024-10-11 13:40:59,182 - INFO - 6sM2JCBjZprP7JLMTZZSxX Hum genre: post-hardcore added
# 2024-10-11 13:40:59,182 - INFO - 6sM2JCBjZprP7JLMTZZSxX Hum genre: spacegrunge added
# 2024-10-11 13:40:59,190 - INFO - Track: 6lQPjlK9jPN9oPnSltqDXR Work All Day added
# 2024-10-11 13:40:59,198 - INFO - Updated audio features for 6lQPjlK9jPN9oPnSltqDXR Work All Day
# 2024-10-11 13:40:59,206 - INFO - Track: 6lQVpykjhYEA9LK7hZi5Yx The Trance Is the Motion added
# 2024-10-11 13:40:59,214 - INFO - Updated audio features for 6lQVpykjhYEA9LK7hZi5Yx The Trance Is the Motion
# 2024-10-11 13:40:59,222 - INFO - Track: 6lRvw8k9ef6YIuJlPLesMu Swedish Pagans - Live @ Wacken 2015 added
# 2024-10-11 13:40:59,230 - INFO - Updated audio features for 6lRvw8k9ef6YIuJlPLesMu Swedish Pagans - Live @ Wacken 2015
# 2024-10-11 13:40:59,247 - INFO - Track: 6lS2jdGhJvy0M1gDM8spDy Melody Lane added
# 2024-10-11 13:40:59,247 - INFO - Updated audio features for 6lS2jdGhJvy0M1gDM8spDy Melody Lane
# 2024-10-11 13:40:59,263 - INFO - Track: 6lSS5pQ7NA0oqC2UU10fFK The Nature Of The Beast - Live in Worcester, MA / November 2019 added
# 2024-10-11 13:40:59,263 - INFO - Updated audio features for 6lSS5pQ7NA0oqC2UU10fFK The Nature Of The Beast - Live in Worcester, MA / November 2019
# 2024-10-11 13:40:59,271 - INFO - Track: 6lSnbMJwCnOzTfBPa0smKK Ancient Gods added
# 2024-10-11 13:40:59,279 - INFO - Updated audio features for 6lSnbMJwCnOzTfBPa0smKK Ancient Gods
# 2024-10-11 13:40:59,295 - INFO - Track: 6lTLgWznUomxzmQpkqGPdF What About Me (feat. Post Malone) added
# 2024-10-11 13:40:59,298 - INFO - Updated audio features for 6lTLgWznUomxzmQpkqGPdF What About Me (feat. Post Malone)
# 2024-10-11 13:40:59,303 - INFO - About to make an album call
# 2024-10-11 13:41:04,379 - INFO - Album: What About Me added
# 2024-10-11 13:41:04,387 - INFO - Track: 6lUEeF62McRG0g57k2n5tK Singularity added
# 2024-10-11 13:41:04,395 - INFO - Updated audio features for 6lUEeF62McRG0g57k2n5tK Singularity
# 2024-10-11 13:41:04,403 - INFO - Track: 6lUXneXZ9jc3HSMHgd8oqh How Can You Mend a Broken Heart added
# 2024-10-11 13:41:04,411 - INFO - Updated audio features for 6lUXneXZ9jc3HSMHgd8oqh How Can You Mend a Broken Heart
# 2024-10-11 13:41:04,419 - INFO - Track: 6lUjedsIIKRBdyNMpdBbai Proactive Evolution added
# 2024-10-11 13:41:04,419 - INFO - Updated audio features for 6lUjedsIIKRBdyNMpdBbai Proactive Evolution
# 2024-10-11 13:41:04,427 - INFO - About to make an album call
# 2024-10-11 13:41:09,495 - INFO - Album: Proactive Evolution added
# 2024-10-11 13:41:09,503 - INFO - Track: 6lUyyCRoT2wvtGlQQEpk3U That House added
# 2024-10-11 13:41:09,511 - INFO - Updated audio features for 6lUyyCRoT2wvtGlQQEpk3U That House
# 2024-10-11 13:41:09,519 - INFO - Track: 6lWFQo5NuR3y8Q6CHIRatA Elimination added
# 2024-10-11 13:41:09,527 - INFO - Updated audio features for 6lWFQo5NuR3y8Q6CHIRatA Elimination
# 2024-10-11 13:41:09,543 - INFO - Track: 6lXECPIIcucEYXgdTe9vZG Man of War added
# 2024-10-11 13:41:09,543 - INFO - Updated audio features for 6lXECPIIcucEYXgdTe9vZG Man of War
# 2024-10-11 13:41:09,551 - INFO - Track: 6lXSdhCJlyM3Tv6PBaFo5V Prowler - 2015 Remaster added
# 2024-10-11 13:41:09,559 - INFO - Updated audio features for 6lXSdhCJlyM3Tv6PBaFo5V Prowler - 2015 Remaster
# 2024-10-11 13:41:09,575 - INFO - Track: 6lZJlAPwtaEp8UDUvmiU3e Whiplash (Live in Mexico City) added
# 2024-10-11 13:41:09,584 - INFO - Updated audio features for 6lZJlAPwtaEp8UDUvmiU3e Whiplash (Live in Mexico City)
# 2024-10-11 13:41:09,592 - INFO - Track: 6lZadw4xVrq6bfYmPsNaUC Gates added
# 2024-10-11 13:41:09,600 - INFO - Updated audio features for 6lZadw4xVrq6bfYmPsNaUC Gates
# 2024-10-11 13:41:09,609 - INFO - Track: 6lZeAGXROog38eHr2ucBN9 Candyman - 2001 Remaster added
# 2024-10-11 13:41:09,616 - INFO - Updated audio features for 6lZeAGXROog38eHr2ucBN9 Candyman - 2001 Remaster
# 2024-10-11 13:41:09,624 - INFO - Track: 6lZlWE53RRQeccTEYfBuMW Be Sweet - Remastered added
# 2024-10-11 13:41:09,632 - INFO - Updated audio features for 6lZlWE53RRQeccTEYfBuMW Be Sweet - Remastered
# 2024-10-11 13:41:09,640 - INFO - Track: 6lZwlaCaFbZh0E0GEqDGEe Panama added
# 2024-10-11 13:41:09,648 - INFO - Updated audio features for 6lZwlaCaFbZh0E0GEqDGEe Panama
# 2024-10-11 13:41:09,648 - INFO - About to make an artist call
# 2024-10-11 13:41:14,711 - INFO - Artist: 7dLfLSHlZABDEVOd54F6XY The Originalz added
# 2024-10-11 13:41:14,719 - INFO - Track: 6lat8Yua6HyTEvN812YrJF Never Odd or Even (Live) added
# 2024-10-11 13:41:14,727 - INFO - Updated audio features for 6lat8Yua6HyTEvN812YrJF Never Odd or Even (Live)
# 2024-10-11 13:41:14,727 - INFO - Tracks, albums, artists, and audio features committed
# 2024-10-11 13:41:14,759 - INFO - New tracks or track artists found in batch starting at index 39650.
# 2024-10-11 13:41:14,759 - INFO - About to make a tracks call
# 2024-10-11 13:41:20,121 - INFO - Track artist: track 6lazC1rUzvAStKfdvrOFcl, artist Perpetual Groove added
# 2024-10-11 13:41:20,121 - INFO - Track artist: track 6lb0ovGSkfRpztxpyXHUKR, artist Akuma Kira added
# 2024-10-11 13:41:20,121 - INFO - Track artist: track 6ld2B6mT4gVMyrPDDEDkkZ, artist Spiritbox added
# 2024-10-11 13:41:20,121 - INFO - Track artist: track 6ldFZdrhzSw0SXLgz6d7bZ, artist Tortoise added
# 2024-10-11 13:41:20,121 - INFO - Track artist: track 6ldFZdrhzSw0SXLgz6d7bZ, artist The Ex added
# 2024-10-11 13:41:20,129 - INFO - Track artist: track 6ldaKIHMZS27kVoAm0ecXY, artist Noisia added
# 2024-10-11 13:41:20,129 - INFO - Track artist: track 6le9zgS2y7MQKvDmmGABDW, artist Be'lakor added
# 2024-10-11 13:41:20,129 - INFO - Track artist: track 6lf4JuyW4IWuGy8Aul3mtj, artist Virulent Depravity added
# 2024-10-11 13:41:20,129 - INFO - Track artist: track 6lgX0oGAbSJ77Qs0MW9tNj, artist The Disco Biscuits added
# 2024-10-11 13:41:20,129 - INFO - Track artist: track 6lgXm8EVHAJLKF68vyIybn, artist Korn added
# 2024-10-11 13:41:20,137 - INFO - Track artist: track 6lgcHHS1Uy2JCiNQLFf0wy, artist Abiotic added
# 2024-10-11 13:41:20,137 - INFO - Track artist: track 6lgkhf5XLGA2wvgFeTy2cq, artist Wayne Shorter added
# 2024-10-11 13:41:20,137 - INFO - Track artist: track 6lhWqXh5VGQPMXTnNvOLd8, artist Weakened Friends added
# 2024-10-11 13:41:20,137 - INFO - Track artist: track 6liHSwsSE9HLjGTchHRkEF, artist Dawn Of Ashes added
# 2024-10-11 13:41:20,137 - INFO - Track artist: track 6lilJagMSnCKnOsOdNw1mv, artist Shakey Graves added
# 2024-10-11 13:41:20,137 - INFO - Track artist: track 6lilJagMSnCKnOsOdNw1mv, artist Esmé Patterson added
# 2024-10-11 13:41:20,145 - INFO - Track artist: track 6lj90SlDI7l1xDLVuxEFDH, artist Team Sleep added
# 2024-10-11 13:41:20,145 - INFO - Track artist: track 6lj9KCNJ1qrrxEXxnpNWoj, artist Closure in Moscow added
# 2024-10-11 13:41:20,145 - INFO - Track artist: track 6ljBM9csnrmXPapV1jLzO0, artist Deafheaven added
# 2024-10-11 13:41:20,145 - INFO - Track artist: track 6lk69KJgnwXwPThivRdMau, artist NOTHING MORE added
# 2024-10-11 13:41:20,145 - INFO - Track artist: track 6lkL4fWwntYU15StiTAx1W, artist Fuck Buttons added
# 2024-10-11 13:41:20,145 - INFO - Track artist: track 6llKhGszlFHtOx3SDACc4Z, artist Thys added
# 2024-10-11 13:41:20,154 - INFO - Track artist: track 6llKhGszlFHtOx3SDACc4Z, artist Lordel added
# 2024-10-11 13:41:20,154 - INFO - Track artist: track 6llKhGszlFHtOx3SDACc4Z, artist Halogenix added
# 2024-10-11 13:41:20,154 - INFO - Track artist: track 6llsY8VcJBzFtjV1PKs8dN, artist Wolf & Bear added
# 2024-10-11 13:41:20,154 - INFO - Track artist: track 6lmCi5eWpn8ouYkaU9RMLm, artist 3TEETH added
# 2024-10-11 13:41:20,154 - INFO - Track artist: track 6lnCOJa3S9sAfK6qj5eMAT, artist Dabin added
# 2024-10-11 13:41:20,161 - INFO - Track artist: track 6lnCOJa3S9sAfK6qj5eMAT, artist NURKO added
# 2024-10-11 13:41:20,161 - INFO - Track artist: track 6lnCOJa3S9sAfK6qj5eMAT, artist Donovan Woods added
# 2024-10-11 13:41:20,161 - INFO - Track artist: track 6lnZW2wFfcTABaoRJUgMyx, artist Neutral Milk Hotel added
# 2024-10-11 13:41:20,161 - INFO - Track artist: track 6loAICkAJ8doNOragHkl5c, artist Thank You Scientist added
# 2024-10-11 13:41:20,161 - INFO - Track artist: track 6lq8RBrWNRhWhNX41h3BWZ, artist Pinegrove added
# 2024-10-11 13:41:20,169 - INFO - Track artist: track 6lqECrP4Jp1wrbyKkjcn9o, artist Archy Marshall added
# 2024-10-11 13:41:20,169 - INFO - Track artist: track 6lqsBd1CrWBte6IwijE1cr, artist Miracle Of Sound added
# 2024-10-11 13:41:20,169 - INFO - Track artist: track 6lqsBd1CrWBte6IwijE1cr, artist Aviators added
# 2024-10-11 13:41:20,169 - INFO - Track artist: track 6lr1ebFsMd98EUlvuj4LXf, artist Nine Inch Nails added
# 2024-10-11 13:41:20,169 - INFO - Track artist: track 6lsFGDo1IEEPFKh94c9kFe, artist Ariana DeBose added
# 2024-10-11 13:41:20,169 - INFO - Track artist: track 6lsFGDo1IEEPFKh94c9kFe, artist Sasha Hutchings added
# 2024-10-11 13:41:20,178 - INFO - Track artist: track 6lsFGDo1IEEPFKh94c9kFe, artist Ephraim Sykes added
# 2024-10-11 13:41:20,178 - INFO - Track artist: track 6lsFGDo1IEEPFKh94c9kFe, artist Lin-Manuel Miranda added
# 2024-10-11 13:41:20,178 - INFO - Track artist: track 6lsFGDo1IEEPFKh94c9kFe, artist Original Broadway Cast of Hamilton added
# 2024-10-11 13:41:20,178 - INFO - Track artist: track 6lsFGDo1IEEPFKh94c9kFe, artist Anthony Ramos added
# 2024-10-11 13:41:20,178 - INFO - Track artist: track 6lt8iodSkYWEV0ifKCSlfg, artist Future added
# 2024-10-11 13:41:20,186 - INFO - Track artist: track 6lt8iodSkYWEV0ifKCSlfg, artist Lil Uzi Vert added
# 2024-10-11 13:41:20,186 - INFO - Track artist: track 6ltcWFTmyRQbSNCNOTK0uM, artist Emotional Oranges added
# 2024-10-11 13:41:20,186 - INFO - Track artist: track 6ltcWFTmyRQbSNCNOTK0uM, artist Biig Piig added
# 2024-10-11 13:41:20,186 - INFO - Track artist: track 6ltgT0C1ElvvgLSCi7J3IH, artist Fuming Mouth added
# 2024-10-11 13:41:20,186 - INFO - Track artist: track 6ltwanTt7xjvZ3rPayPppS, artist Big Sean added
# 2024-10-11 13:41:20,186 - INFO - Track artist: track 6luBKkFUt5wTwz7hpLhp12, artist Lil Yachty added
# 2024-10-11 13:41:20,194 - INFO - Track artist: track 6lv17v36tF8al3gfOG34iq, artist Antonio Vivaldi added
# 2024-10-11 13:41:20,194 - INFO - Track artist: track 6lv17v36tF8al3gfOG34iq, artist Peter Whelan added
# 2024-10-11 13:41:20,194 - INFO - Track artist: track 6lv17v36tF8al3gfOG34iq, artist La Serenissima added
# 2024-10-11 13:41:20,194 - INFO - Track artist: track 6lv17v36tF8al3gfOG34iq, artist Adrian Chandler added
# 2024-10-11 13:41:20,194 - INFO - Track artist: track 6lvNLD1XRU5paMwWH0RGRI, artist A Perfect Circle added
# 2024-10-11 13:41:20,202 - INFO - Track artist: track 6lvQMMJKBPRx4JmSYyHJNs, artist The National added
# 2024-10-11 13:41:20,202 - INFO - Track artist: track 6lvX418bOevUB7dVIuXcBj, artist Azzecca added
# 2024-10-11 13:41:20,202 - INFO - Track artist: track 6lvdUaqmXeKW1R4riteb0M, artist Space Jesus added
# 2024-10-11 13:41:20,202 - INFO - Track artist: track 6lvdUaqmXeKW1R4riteb0M, artist Digital Ethos added
# 2024-10-11 13:41:20,202 - INFO - Track artist: track 6lw0X91kgXC7qMGG6L7GlL, artist Phish added
# 2024-10-11 13:41:20,210 - INFO - Track artist: track 6lwJfJeCeeqzBnt0TR3ZDk, artist Dizgo added
# 2024-10-11 13:41:20,210 - INFO - Track artist: track 6lwK3ARoB63T7rW3d4i6HF, artist Grateful Dead added
# 2024-10-11 13:41:20,210 - INFO - Track artist: track 6lwK3ARoB63T7rW3d4i6HF, artist Merle Saunders added
# 2024-10-11 13:41:20,210 - INFO - Track artist: track 6lxYQZjmMa2tWHadsj54Ur, artist The Teskey Brothers added
# 2024-10-11 13:41:20,210 - INFO - Track artist: track 6lxfQB7XDMou5U9YB2r9ow, artist Closure in Moscow added
# 2024-10-11 13:41:20,210 - INFO - Track artist: track 6lyTx22EvehCa9UwYS2o93, artist Chimaira added
# 2024-10-11 13:41:20,219 - INFO - Track artist: track 6lypN6c1prGT62xF8KVTBL, artist Skeptical added
# 2024-10-11 13:41:20,219 - INFO - Track artist: track 6lzlRAp5VqLLF78PwnfHjq, artist Sara Bareilles added
# 2024-10-11 13:41:20,219 - INFO - Track artist: track 6m15fdzF3hMvhLZw34vPjO, artist Papadosio added
# 2024-10-11 13:41:20,219 - INFO - Track artist: track 6m1njvWGl1t1YSczTG8Nu1, artist Dance Gavin Dance added
# 2024-10-11 13:41:20,227 - INFO - Track artists committed
# 2024-10-11 13:41:20,227 - INFO - About to make an audio features call
# 2024-10-11 13:41:25,434 - INFO - Track: 6lazC1rUzvAStKfdvrOFcl Upswing added
# 2024-10-11 13:41:25,442 - INFO - Updated audio features for 6lazC1rUzvAStKfdvrOFcl Upswing
# 2024-10-11 13:41:25,450 - INFO - About to make an album call
# 2024-10-11 13:41:30,528 - INFO - Album: Upswing added
# 2024-10-11 13:41:30,536 - INFO - Track: 6lb0ovGSkfRpztxpyXHUKR What Do You Offer added
# 2024-10-11 13:41:30,544 - INFO - Updated audio features for 6lb0ovGSkfRpztxpyXHUKR What Do You Offer
# 2024-10-11 13:41:30,552 - INFO - Track: 6ld2B6mT4gVMyrPDDEDkkZ Belcarra added
# 2024-10-11 13:41:30,552 - INFO - Updated audio features for 6ld2B6mT4gVMyrPDDEDkkZ Belcarra
# 2024-10-11 13:41:30,560 - INFO - About to make an album call
# 2024-10-11 13:41:35,630 - INFO - Album: Singles Collection added
# 2024-10-11 13:41:35,638 - INFO - Track: 6ldFZdrhzSw0SXLgz6d7bZ The Lawn Of The Limp added
# 2024-10-11 13:41:35,638 - INFO - Updated audio features for 6ldFZdrhzSw0SXLgz6d7bZ The Lawn Of The Limp
# 2024-10-11 13:41:35,646 - INFO - About to make an album call
# 2024-10-11 13:41:40,742 - INFO - Album: In The Fishtank 5 added
# 2024-10-11 13:41:40,742 - INFO - About to make an artist call
# 2024-10-11 13:41:45,814 - INFO - Artist: 5JjsLpZlE0oSu9opRGQYWm The Ex added
# 2024-10-11 13:41:45,814 - INFO - 5JjsLpZlE0oSu9opRGQYWm The Ex genre: art punk added
# 2024-10-11 13:41:45,814 - INFO - 5JjsLpZlE0oSu9opRGQYWm The Ex genre: experimental rock added
# 2024-10-11 13:41:45,822 - INFO - Track: 6ldaKIHMZS27kVoAm0ecXY Whiskers added
# 2024-10-11 13:41:45,830 - INFO - Updated audio features for 6ldaKIHMZS27kVoAm0ecXY Whiskers
# 2024-10-11 13:41:45,838 - INFO - Track: 6le9zgS2y7MQKvDmmGABDW Roots to Sever added
# 2024-10-11 13:41:45,848 - INFO - Updated audio features for 6le9zgS2y7MQKvDmmGABDW Roots to Sever
# 2024-10-11 13:41:45,855 - INFO - Track: 6lf4JuyW4IWuGy8Aul3mtj Crushed by Futuristic Filth added
# 2024-10-11 13:41:45,863 - INFO - Updated audio features for 6lf4JuyW4IWuGy8Aul3mtj Crushed by Futuristic Filth
# 2024-10-11 13:41:45,879 - INFO - Track: 6lgX0oGAbSJ77Qs0MW9tNj Intro added
# 2024-10-11 13:41:45,887 - INFO - Updated audio features for 6lgX0oGAbSJ77Qs0MW9tNj Intro
# 2024-10-11 13:41:45,895 - INFO - Track: 6lgXm8EVHAJLKF68vyIybn Got the Life added
# 2024-10-11 13:41:45,903 - INFO - Updated audio features for 6lgXm8EVHAJLKF68vyIybn Got the Life
# 2024-10-11 13:41:45,911 - INFO - Track: 6lgcHHS1Uy2JCiNQLFf0wy Gyokusai added
# 2024-10-11 13:41:45,911 - INFO - Updated audio features for 6lgcHHS1Uy2JCiNQLFf0wy Gyokusai
# 2024-10-11 13:41:45,928 - INFO - Track: 6lgkhf5XLGA2wvgFeTy2cq Fee-Fi-Fo-Fum - Remastered1998/Rudy Van Gelder Edition added
# 2024-10-11 13:41:45,928 - INFO - Updated audio features for 6lgkhf5XLGA2wvgFeTy2cq Fee-Fi-Fo-Fum - Remastered1998/Rudy Van Gelder Edition
# 2024-10-11 13:41:45,944 - INFO - Track: 6lhWqXh5VGQPMXTnNvOLd8 Common Blah added
# 2024-10-11 13:41:45,949 - INFO - Updated audio features for 6lhWqXh5VGQPMXTnNvOLd8 Common Blah
# 2024-10-11 13:41:45,960 - INFO - Track: 6liHSwsSE9HLjGTchHRkEF Anatomy of the Soul added
# 2024-10-11 13:41:45,960 - INFO - Updated audio features for 6liHSwsSE9HLjGTchHRkEF Anatomy of the Soul
# 2024-10-11 13:41:45,976 - INFO - Track: 6lilJagMSnCKnOsOdNw1mv Dearly Departed - Live from Spotify SXSW 2014 (feat. Esme Patterson) added
# 2024-10-11 13:41:45,992 - INFO - Updated audio features for 6lilJagMSnCKnOsOdNw1mv Dearly Departed - Live from Spotify SXSW 2014 (feat. Esme Patterson)
# 2024-10-11 13:41:46,000 - INFO - Track: 6lj90SlDI7l1xDLVuxEFDH Ever (Foreign Flag) added
# 2024-10-11 13:41:46,017 - INFO - Updated audio features for 6lj90SlDI7l1xDLVuxEFDH Ever (Foreign Flag)
# 2024-10-11 13:41:46,025 - INFO - Track: 6lj9KCNJ1qrrxEXxnpNWoj Pink Lemonade added
# 2024-10-11 13:41:46,033 - INFO - Updated audio features for 6lj9KCNJ1qrrxEXxnpNWoj Pink Lemonade
# 2024-10-11 13:41:46,041 - INFO - Track: 6ljBM9csnrmXPapV1jLzO0 The Pecan Tree added
# 2024-10-11 13:41:46,049 - INFO - Updated audio features for 6ljBM9csnrmXPapV1jLzO0 The Pecan Tree
# 2024-10-11 13:41:46,057 - INFO - Track: 6lk69KJgnwXwPThivRdMau If I Were added
# 2024-10-11 13:41:46,065 - INFO - Updated audio features for 6lk69KJgnwXwPThivRdMau If I Were
# 2024-10-11 13:41:46,073 - INFO - Track: 6lkL4fWwntYU15StiTAx1W Year of the Dog added
# 2024-10-11 13:41:46,081 - INFO - Updated audio features for 6lkL4fWwntYU15StiTAx1W Year of the Dog
# 2024-10-11 13:41:46,089 - INFO - Track: 6llKhGszlFHtOx3SDACc4Z Unwound added
# 2024-10-11 13:41:46,097 - INFO - Updated audio features for 6llKhGszlFHtOx3SDACc4Z Unwound
# 2024-10-11 13:41:46,105 - INFO - About to make an artist call
# 2024-10-11 13:41:51,155 - INFO - Artist: 6JINZdc7A864q4L5N4p2y4 Lordel added
# 2024-10-11 13:41:51,164 - INFO - Track: 6llsY8VcJBzFtjV1PKs8dN Everything Is Going Grey added
# 2024-10-11 13:41:51,172 - INFO - Updated audio features for 6llsY8VcJBzFtjV1PKs8dN Everything Is Going Grey
# 2024-10-11 13:41:51,180 - INFO - Track: 6lmCi5eWpn8ouYkaU9RMLm THE FALL added
# 2024-10-11 13:41:51,188 - INFO - Updated audio features for 6lmCi5eWpn8ouYkaU9RMLm THE FALL
# 2024-10-11 13:41:51,196 - INFO - Track: 6lnCOJa3S9sAfK6qj5eMAT When This Is Over added
# 2024-10-11 13:41:51,204 - INFO - Updated audio features for 6lnCOJa3S9sAfK6qj5eMAT When This Is Over
# 2024-10-11 13:41:51,212 - INFO - Track: 6lnZW2wFfcTABaoRJUgMyx Two-Headed Boy Pt. 2 added
# 2024-10-11 13:41:51,220 - INFO - Updated audio features for 6lnZW2wFfcTABaoRJUgMyx Two-Headed Boy Pt. 2
# 2024-10-11 13:41:51,228 - INFO - Track: 6loAICkAJ8doNOragHkl5c Wrinkle added
# 2024-10-11 13:41:51,236 - INFO - Updated audio features for 6loAICkAJ8doNOragHkl5c Wrinkle
# 2024-10-11 13:41:51,244 - INFO - Track: 6lq8RBrWNRhWhNX41h3BWZ Aphasia - Montclair, NJ added
# 2024-10-11 13:41:51,255 - INFO - Updated audio features for 6lq8RBrWNRhWhNX41h3BWZ Aphasia - Montclair, NJ
# 2024-10-11 13:41:51,261 - INFO - Track: 6lqECrP4Jp1wrbyKkjcn9o Swell added
# 2024-10-11 13:41:51,269 - INFO - Updated audio features for 6lqECrP4Jp1wrbyKkjcn9o Swell
# 2024-10-11 13:41:51,277 - INFO - Track: 6lqsBd1CrWBte6IwijE1cr A Thousand Eyes added
# 2024-10-11 13:41:51,285 - INFO - Updated audio features for 6lqsBd1CrWBte6IwijE1cr A Thousand Eyes
# 2024-10-11 13:41:51,293 - INFO - About to make an album call
# 2024-10-11 13:41:56,372 - INFO - Album: A Thousand Eyes added
# 2024-10-11 13:41:56,372 - INFO - About to make an artist call
# 2024-10-11 13:42:01,578 - INFO - Artist: 4FmJD0mpgQ70SNt2EKK8tq Miracle Of Sound added
# 2024-10-11 13:42:01,578 - INFO - 4FmJD0mpgQ70SNt2EKK8tq Miracle Of Sound genre: antiviral pop added
# 2024-10-11 13:42:01,578 - INFO - 4FmJD0mpgQ70SNt2EKK8tq Miracle Of Sound genre: irish metal added
# 2024-10-11 13:42:01,578 - INFO - 4FmJD0mpgQ70SNt2EKK8tq Miracle Of Sound genre: shanty added
# 2024-10-11 13:42:01,578 - INFO - About to make an artist call
# 2024-10-11 13:42:06,681 - INFO - Artist: 3xNCp8cktZ1IGwRregR2yO Aviators added
# 2024-10-11 13:42:06,681 - INFO - 3xNCp8cktZ1IGwRregR2yO Aviators genre: otacore added
# 2024-10-11 13:42:06,689 - INFO - Track: 6lr1ebFsMd98EUlvuj4LXf 20 Ghosts III added
# 2024-10-11 13:42:06,697 - INFO - Updated audio features for 6lr1ebFsMd98EUlvuj4LXf 20 Ghosts III
# 2024-10-11 13:42:06,705 - INFO - Track: 6lsFGDo1IEEPFKh94c9kFe Blow Us All Away added
# 2024-10-11 13:42:06,714 - INFO - Updated audio features for 6lsFGDo1IEEPFKh94c9kFe Blow Us All Away
# 2024-10-11 13:42:06,714 - INFO - About to make an artist call
# 2024-10-11 13:42:11,807 - INFO - Artist: 1Np9GsrPO7dlczjvdehBxs Ariana DeBose added
# 2024-10-11 13:42:11,807 - INFO - 1Np9GsrPO7dlczjvdehBxs Ariana DeBose genre: movie tunes added
# 2024-10-11 13:42:11,807 - INFO - About to make an artist call
# 2024-10-11 13:42:16,864 - INFO - Artist: 0Pg2rEmiZEnmxw4eQwtvsR Sasha Hutchings added
# 2024-10-11 13:42:16,864 - INFO - About to make an artist call
# 2024-10-11 13:42:21,920 - INFO - Artist: 3brilvMAN6ILRUMvaqJWdG Ephraim Sykes added
# 2024-10-11 13:42:21,928 - INFO - Track: 6lt8iodSkYWEV0ifKCSlfg Stripes Like Burberry added
# 2024-10-11 13:42:21,937 - INFO - Updated audio features for 6lt8iodSkYWEV0ifKCSlfg Stripes Like Burberry
# 2024-10-11 13:42:21,945 - INFO - Track: 6ltcWFTmyRQbSNCNOTK0uM Body & Soul (feat. Biig Piig) added
# 2024-10-11 13:42:21,953 - INFO - Updated audio features for 6ltcWFTmyRQbSNCNOTK0uM Body & Soul (feat. Biig Piig)
# 2024-10-11 13:42:21,953 - INFO - About to make an album call
# 2024-10-11 13:42:27,064 - INFO - Album: The Juicebox added
# 2024-10-11 13:42:27,080 - INFO - Track: 6ltgT0C1ElvvgLSCi7J3IH I'll Find You added
# 2024-10-11 13:42:27,089 - INFO - Updated audio features for 6ltgT0C1ElvvgLSCi7J3IH I'll Find You
# 2024-10-11 13:42:27,105 - INFO - Track: 6ltwanTt7xjvZ3rPayPppS Dark Sky (Skyscrapers) added
# 2024-10-11 13:42:27,113 - INFO - Updated audio features for 6ltwanTt7xjvZ3rPayPppS Dark Sky (Skyscrapers)
# ...
# 2024-10-11 15:26:11,246 - INFO - Updated audio features for 7bUMIb3KpgTxDY6LXzrZvt King for a Day
# 2024-10-11 15:26:11,277 - INFO - Track: 7bUcBztfGqO7cSI2gMZeCI Opps (with Yugen Blakrok) added
# 2024-10-11 15:26:11,292 - INFO - Updated audio features for 7bUcBztfGqO7cSI2gMZeCI Opps (with Yugen Blakrok)
# 2024-10-11 15:26:11,292 - INFO - About to make an artist call
# 2024-10-11 15:26:16,360 - INFO - Artist: 3kv1Edgn5HlEWCuEKr1Y9x Yugen Blakrok added
# 2024-10-11 15:26:16,360 - INFO - 3kv1Edgn5HlEWCuEKr1Y9x Yugen Blakrok genre: south african hip hop added
# 2024-10-11 15:26:16,360 - INFO - 3kv1Edgn5HlEWCuEKr1Y9x Yugen Blakrok genre: spiritual hip hop added
# 2024-10-11 15:26:16,422 - INFO - Track: 7bV9iarPkF7RvzR8usJ29b Here to Mars added
# 2024-10-11 15:26:16,501 - INFO - Updated audio features for 7bV9iarPkF7RvzR8usJ29b Here to Mars
# 2024-10-11 15:26:16,516 - INFO - About to make an album call
# 2024-10-11 15:26:21,614 - INFO - Album: Here To Mars added
# 2024-10-11 15:26:21,629 - INFO - Track: 7bVE4dySE2Wrtwy9TZtzVD Melodrama Between Two Entirely Bored Individuals added
# 2024-10-11 15:26:21,645 - INFO - Updated audio features for 7bVE4dySE2Wrtwy9TZtzVD Melodrama Between Two Entirely Bored Individuals
# 2024-10-11 15:26:21,662 - INFO - Track: 7bVbpJ0ZO15CnL95rZ3q1g Purity added
# 2024-10-11 15:26:21,677 - INFO - Updated audio features for 7bVbpJ0ZO15CnL95rZ3q1g Purity
# 2024-10-11 15:26:21,677 - INFO - About to make an album call
# 2024-10-11 15:26:26,823 - INFO - Album: Purity added
# 2024-10-11 15:26:26,839 - INFO - Track: 7bWiQ6WWYmdVoo53ffeIX2 Killer added
# 2024-10-11 15:26:26,886 - INFO - Updated audio features for 7bWiQ6WWYmdVoo53ffeIX2 Killer
# 2024-10-11 15:26:26,917 - INFO - Track: 7bYLlOxx9sFCjS0XfrzDC6 Withering Strands added
# 2024-10-11 15:26:26,949 - INFO - Updated audio features for 7bYLlOxx9sFCjS0XfrzDC6 Withering Strands
# 2024-10-11 15:26:26,980 - INFO - Track: 7bYab61Dffg0ckGLwxglSd Remind added
# 2024-10-11 15:26:26,996 - INFO - Updated audio features for 7bYab61Dffg0ckGLwxglSd Remind
# 2024-10-11 15:26:27,027 - INFO - Track: 7bYwLaOrSHtypXTKfcl5Q1 Come as Your Kids added
# 2024-10-11 15:26:27,043 - INFO - Updated audio features for 7bYwLaOrSHtypXTKfcl5Q1 Come as Your Kids
# 2024-10-11 15:26:27,074 - INFO - Track: 7bafHzGkh71QJhViBaohcm Duck Farm added
# 2024-10-11 15:26:27,090 - INFO - Updated audio features for 7bafHzGkh71QJhViBaohcm Duck Farm
# 2024-10-11 15:26:27,090 - INFO - Tracks, albums, artists, and audio features committed
# 2024-10-11 15:26:27,184 - INFO - New tracks or track artists found in batch starting at index 43300.
# 2024-10-11 15:26:27,184 - INFO - About to make a tracks call
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7ban1bFTZM96OVmKKmZqQw, artist Waxahatchee added
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7bbdNZXwpwMSNAvoxMjJPc, artist Godsmack added
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7behUBBwhex459VBTOH0wT, artist Glassjaw added
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7bhECQOkm2mhmDKAjtyxk8, artist LA Riots added
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7bhECQOkm2mhmDKAjtyxk8, artist Max Styler added
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7bhECQOkm2mhmDKAjtyxk8, artist Laura White added
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7biGSGQSSVJJIjHSVX3j1q, artist Phish added
# 2024-10-11 15:26:32,453 - INFO - Track artist: track 7biThmNOfzA4nZR9h2B6DL, artist Nine Inch Nails added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7biflzjN8c8v5mPuh71lXB, artist LP Giobbi added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7biflzjN8c8v5mPuh71lXB, artist hermixalot added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7bizGQTRSqfXL8kmm1FErk, artist Alejandro Aranda added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7blNhlXimy77PduXyWtmcI, artist boygenius added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7blNhlXimy77PduXyWtmcI, artist Julien Baker added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7blNhlXimy77PduXyWtmcI, artist Phoebe Bridgers added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7blNhlXimy77PduXyWtmcI, artist Lucy Dacus added
# 2024-10-11 15:26:32,469 - INFO - Track artist: track 7blVeauN6UPeewCORqVdCD, artist Disclosure added
# 2024-10-11 15:26:32,483 - INFO - Track artist: track 7blVeauN6UPeewCORqVdCD, artist Mary J. Blige added
# 2024-10-11 15:26:32,485 - INFO - Track artist: track 7boXP1XzIt8QBlmdwQRNUm, artist Peter Frampton added
# 2024-10-11 15:26:32,485 - INFO - Track artist: track 7bp5DfkdK1OAvNJ1U4HfDA, artist GZA added
# 2024-10-11 15:26:32,485 - INFO - Track artist: track 7bp5DfkdK1OAvNJ1U4HfDA, artist Method Man added
# 2024-10-11 15:26:32,485 - INFO - Track artist: track 7bp7QInQ5uIMzYjJqTtjVA, artist Sylvan Esso added
# 2024-10-11 15:26:32,485 - INFO - Track artist: track 7bpLhv750qpx0ENF4GOz4Z, artist Sabaton added
# 2024-10-11 15:26:32,501 - INFO - Track artist: track 7bqhXvRLvm6UxHCfP0IOp8, artist Federico Dubbini added
# 2024-10-11 15:26:32,501 - INFO - Track artist: track 7br4LajZITrs7eNPbwll9R, artist Deftones added
# 2024-10-11 15:26:32,501 - INFO - Track artist: track 7bsQEb4oFKdpAJwor5hOp3, artist Rise Against added
# 2024-10-11 15:26:32,501 - INFO - Track artist: track 7bsaoJIKSDX4XUVIrn102L, artist Grey Code added
# 2024-10-11 15:26:32,501 - INFO - Track artist: track 7btCHWxzbr40QtJ2amRRTr, artist Alabama Shakes added
# 2024-10-11 15:26:32,501 - INFO - Track artist: track 7btb5OkntHhetcsE7snsgS, artist Carcass added
# 2024-10-11 15:26:32,516 - INFO - Track artist: track 7buj9wAHfNChmh12IhJ9YC, artist Giant Panda Guerilla Dub Squad added
# 2024-10-11 15:26:32,516 - INFO - Track artist: track 7bv4gh6n7oMtoo3qSoFXCV, artist DIESEL added
# 2024-10-11 15:26:32,516 - INFO - Track artist: track 7bv4gh6n7oMtoo3qSoFXCV, artist Chassi added
# 2024-10-11 15:26:32,516 - INFO - Track artist: track 7bv4gh6n7oMtoo3qSoFXCV, artist Kozmoz added
# 2024-10-11 15:26:32,516 - INFO - Track artist: track 7bvMExolp5KSmmYFhfbWjr, artist Rivers of Nihil added
# 2024-10-11 15:26:32,516 - INFO - Track artist: track 7bvjehr9hz2Xz9ZJZ1QzgB, artist Sufjan Stevens added
# 2024-10-11 15:26:32,532 - INFO - Track artist: track 7bxBo2l2lncW6UEIvaptoM, artist Psymbionic added
# 2024-10-11 15:26:32,532 - INFO - Track artist: track 7bywjHOc0wSjGGbj04XbVi, artist Feid added
# 2024-10-11 15:26:32,532 - INFO - Track artist: track 7bywjHOc0wSjGGbj04XbVi, artist ATL Jacob added
# 2024-10-11 15:26:32,532 - INFO - Track artist: track 7bz1g3p8UhHmIKpb9whrpG, artist P.O.S added
# 2024-10-11 15:26:32,532 - INFO - Track artist: track 7bzGcUBgNuwg88CVZz1MmG, artist Justin Hawkes added
# 2024-10-11 15:26:32,532 - INFO - Track artist: track 7bzGcUBgNuwg88CVZz1MmG, artist PAV4N added
# 2024-10-11 15:26:32,532 - INFO - Track artist: track 7bzGcUBgNuwg88CVZz1MmG, artist Foreign Beggars added
# 2024-10-11 15:26:32,548 - INFO - Track artist: track 7bzzC7QIfflM9eEj2aqaYX, artist Fleet Foxes added
# 2024-10-11 15:26:32,548 - INFO - Track artist: track 7c0OKGzbNlBL748uIzK1ak, artist The Acacia Strain added
# 2024-10-11 15:26:32,548 - INFO - Track artist: track 7c1Dar0pIAW7w5TzaGjt9t, artist Jane's Addiction added
# 2024-10-11 15:26:32,548 - INFO - Track artist: track 7c2BvqW33kNpb4fpQZU4Ap, artist Kira Skov added
# 2024-10-11 15:26:32,548 - INFO - Track artist: track 7c2BvqW33kNpb4fpQZU4Ap, artist trentemøller added
# 2024-10-11 15:26:32,548 - INFO - Track artist: track 7c2HMEdjUyKSxJWZMG1KaF, artist Giant Panda Guerilla Dub Squad added
# 2024-10-11 15:26:32,548 - INFO - Track artist: track 7c2ublA3ykE4GWLJ4b17Wc, artist Shpongle added
# 2024-10-11 15:26:32,563 - INFO - Track artist: track 7c378mlmubSu7NGkLFa4sN, artist Radiohead added
# 2024-10-11 15:26:32,563 - INFO - Track artist: track 7c3SbTuufigBWURcICnAWy, artist Anderson .Paak added
# 2024-10-11 15:26:32,563 - INFO - Track artist: track 7c3SbTuufigBWURcICnAWy, artist Kendrick Lamar added
# 2024-10-11 15:26:32,563 - INFO - Track artist: track 7c3XA5cpvgPxz2A9XOSvSb, artist Megadeth added
# 2024-10-11 15:26:32,563 - INFO - Track artist: track 7c3rPfekx7vpbB7MNdAHFM, artist The Disco Biscuits added
# 2024-10-11 15:26:32,563 - INFO - Track artist: track 7c4a0KgodCBS8LYF1g3jlM, artist Good Old War added
# 2024-10-11 15:26:32,579 - INFO - Track artist: track 7c6e5vq0kGD5LGo1upkgLS, artist Blawan added
# 2024-10-11 15:26:32,579 - INFO - Track artist: track 7c7ClnE57SwbizNe24XTXe, artist Big Wild added
# 2024-10-11 15:26:32,583 - INFO - Track artist: track 7c8Hl1kaGaunyLBYxXRrtL, artist Goose added
# 2024-10-11 15:26:32,583 - INFO - Track artist: track 7cA3OHUSgQdcG332ZAx8Lj, artist ILLENIUM added
# 2024-10-11 15:26:32,583 - INFO - Track artist: track 7cA3OHUSgQdcG332ZAx8Lj, artist SKYLR added
# 2024-10-11 15:26:32,583 - INFO - Track artist: track 7cBGkq1MFzOaDwZ6oxSPOo, artist In Flames added
# 2024-10-11 15:26:32,583 - INFO - Track artist: track 7cCIBaEjve2ZRkr4l72SNF, artist Rising Appalachia added
# 2024-10-11 15:26:32,583 - INFO - Track artist: track 7cCmDDmViLQoytNvHmFvjS, artist Avenged Sevenfold added
# 2024-10-11 15:26:32,595 - INFO - Track artist: track 7cDMcALsaDm3IhKD5xh4jI, artist Converge added
# 2024-10-11 15:26:32,595 - INFO - Track artist: track 7cE9zaBRx8uSvACUPyTrNK, artist Weedeater added
# 2024-10-11 15:26:32,595 - INFO - Track artist: track 7cFFhb9Wz2ZXLSpEk2VDKd, artist Jaden added
# 2024-10-11 15:26:32,595 - INFO - Track artist: track 7cFXll3xmQheO92tcYut9B, artist Pretty Lights added
# 2024-10-11 15:26:32,595 - INFO - Track artists committed
# 2024-10-11 15:26:32,595 - INFO - About to make an audio features call
# 2024-10-11 15:26:37,774 - INFO - Track: 7ban1bFTZM96OVmKKmZqQw The Eye added
# 2024-10-11 15:26:37,790 - INFO - Updated audio features for 7ban1bFTZM96OVmKKmZqQw The Eye
# 2024-10-11 15:26:37,810 - INFO - Track: 7bbdNZXwpwMSNAvoxMjJPc Speak added
# 2024-10-11 15:26:37,823 - INFO - Updated audio features for 7bbdNZXwpwMSNAvoxMjJPc Speak
# 2024-10-11 15:26:37,840 - INFO - Track: 7behUBBwhex459VBTOH0wT new white extremity added
# 2024-10-11 15:26:37,856 - INFO - Updated audio features for 7behUBBwhex459VBTOH0wT new white extremity
# 2024-10-11 15:26:37,874 - INFO - Track: 7bhECQOkm2mhmDKAjtyxk8 I Call That Love (feat. Laura White) added
# 2024-10-11 15:26:37,886 - INFO - Updated audio features for 7bhECQOkm2mhmDKAjtyxk8 I Call That Love (feat. Laura White)
# 2024-10-11 15:26:37,888 - INFO - About to make an album call
# 2024-10-11 15:26:42,972 - INFO - Album: I Call That Love (feat. Laura White) added
# 2024-10-11 15:26:42,975 - INFO - About to make an artist call
# 2024-10-11 15:26:48,073 - INFO - Artist: 5NnQdLx16ClNP5haoGdjk7 LA Riots added
# 2024-10-11 15:26:48,076 - INFO - About to make an artist call
# 2024-10-11 15:26:53,151 - INFO - Artist: 4eWvHAcWh3Hq6DYJ9K3mD4 Laura White added
# 2024-10-11 15:26:53,151 - INFO - 4eWvHAcWh3Hq6DYJ9K3mD4 Laura White genre: talent show added
# 2024-10-11 15:26:53,166 - INFO - Track: 7biGSGQSSVJJIjHSVX3j1q Wolfman's Brother added
# 2024-10-11 15:26:53,184 - INFO - Updated audio features for 7biGSGQSSVJJIjHSVX3j1q Wolfman's Brother
# 2024-10-11 15:26:53,200 - INFO - Track: 7biThmNOfzA4nZR9h2B6DL Head Like a Hole added
# 2024-10-11 15:26:53,207 - INFO - Updated audio features for 7biThmNOfzA4nZR9h2B6DL Head Like a Hole
# 2024-10-11 15:26:53,207 - INFO - About to make an album call
# 2024-10-11 15:26:58,313 - INFO - Album: Pretty Hate Machine [2010 Remaster] added
# 2024-10-11 15:26:58,315 - INFO - Track: 7biflzjN8c8v5mPuh71lXB Togetherness added
# 2024-10-11 15:26:58,329 - INFO - Updated audio features for 7biflzjN8c8v5mPuh71lXB Togetherness
# 2024-10-11 15:26:58,345 - INFO - Track: 7bizGQTRSqfXL8kmm1FErk Judas added
# 2024-10-11 15:26:58,360 - INFO - Updated audio features for 7bizGQTRSqfXL8kmm1FErk Judas
# 2024-10-11 15:26:58,376 - INFO - Track: 7blNhlXimy77PduXyWtmcI Salt In The Wound added
# 2024-10-11 15:26:58,376 - INFO - Updated audio features for 7blNhlXimy77PduXyWtmcI Salt In The Wound
# 2024-10-11 15:26:58,391 - INFO - Track: 7blVeauN6UPeewCORqVdCD F For You added
# 2024-10-11 15:26:58,407 - INFO - Updated audio features for 7blVeauN6UPeewCORqVdCD F For You
# 2024-10-11 15:26:58,423 - INFO - Track: 7boXP1XzIt8QBlmdwQRNUm (I’m A) Road Runner - Live added
# 2024-10-11 15:26:58,423 - INFO - Updated audio features for 7boXP1XzIt8QBlmdwQRNUm (I’m A) Road Runner - Live
# 2024-10-11 15:26:58,439 - INFO - Track: 7bp5DfkdK1OAvNJ1U4HfDA Shadowboxin' added
# 2024-10-11 15:26:58,439 - INFO - Updated audio features for 7bp5DfkdK1OAvNJ1U4HfDA Shadowboxin'
# 2024-10-11 15:26:58,454 - INFO - Track: 7bp7QInQ5uIMzYjJqTtjVA Hey Mami added
# 2024-10-11 15:26:58,470 - INFO - Updated audio features for 7bp7QInQ5uIMzYjJqTtjVA Hey Mami
# 2024-10-11 15:26:58,486 - INFO - Track: 7bpLhv750qpx0ENF4GOz4Z 40:1 added
# 2024-10-11 15:26:58,501 - INFO - Updated audio features for 7bpLhv750qpx0ENF4GOz4Z 40:1
# 2024-10-11 15:26:58,501 - INFO - Track: 7bqhXvRLvm6UxHCfP0IOp8 Always on My Mind added
# 2024-10-11 15:26:58,517 - INFO - Updated audio features for 7bqhXvRLvm6UxHCfP0IOp8 Always on My Mind
# 2024-10-11 15:26:58,517 - INFO - About to make an album call
# 2024-10-11 15:27:03,601 - INFO - Album: Kingdom Hearts World added
# 2024-10-11 15:27:03,601 - INFO - About to make an artist call
# 2024-10-11 15:27:08,667 - INFO - Artist: 2yiXMorEbGKw4gPLK7x8U4 Federico Dubbini added
# 2024-10-11 15:27:08,667 - INFO - 2yiXMorEbGKw4gPLK7x8U4 Federico Dubbini genre: japanese vgm added
# 2024-10-11 15:27:08,683 - INFO - Track: 7br4LajZITrs7eNPbwll9R U,U,D,D,L,R,L,R,A,B,Select,Start added
# 2024-10-11 15:27:08,698 - INFO - Updated audio features for 7br4LajZITrs7eNPbwll9R U,U,D,D,L,R,L,R,A,B,Select,Start
# 2024-10-11 15:27:08,714 - INFO - Track: 7bsQEb4oFKdpAJwor5hOp3 Behind Closed Doors added
# 2024-10-11 15:27:08,730 - INFO - Updated audio features for 7bsQEb4oFKdpAJwor5hOp3 Behind Closed Doors
# 2024-10-11 15:27:08,730 - INFO - Track: 7bsaoJIKSDX4XUVIrn102L Ethics added
# 2024-10-11 15:27:08,745 - INFO - Updated audio features for 7bsaoJIKSDX4XUVIrn102L Ethics
# 2024-10-11 15:27:08,745 - INFO - Track: 7btCHWxzbr40QtJ2amRRTr I Found You added
# 2024-10-11 15:27:08,761 - INFO - Updated audio features for 7btCHWxzbr40QtJ2amRRTr I Found You
# 2024-10-11 15:27:08,777 - INFO - Track: 7btb5OkntHhetcsE7snsgS Carneous Cacoffiny added
# 2024-10-11 15:27:08,777 - INFO - Updated audio features for 7btb5OkntHhetcsE7snsgS Carneous Cacoffiny
# 2024-10-11 15:27:08,792 - INFO - Track: 7buj9wAHfNChmh12IhJ9YC Ok (Aggie Theatre - Fort Collins, Co - April 10, 2010) added
# 2024-10-11 15:27:08,792 - INFO - Updated audio features for 7buj9wAHfNChmh12IhJ9YC Ok (Aggie Theatre - Fort Collins, Co - April 10, 2010)
# 2024-10-11 15:27:08,808 - INFO - Track: 7bv4gh6n7oMtoo3qSoFXCV HIT EM LIKE added
# 2024-10-11 15:27:08,829 - INFO - Updated audio features for 7bv4gh6n7oMtoo3qSoFXCV HIT EM LIKE
# 2024-10-11 15:27:08,829 - INFO - About to make an artist call
# 2024-10-11 15:27:13,936 - INFO - Artist: 4jwHh8156lpD0ifm9bUCz4 Kozmoz added
# 2024-10-11 15:27:13,938 - INFO - 4jwHh8156lpD0ifm9bUCz4 Kozmoz genre: dubstep added
# 2024-10-11 15:27:13,938 - INFO - 4jwHh8156lpD0ifm9bUCz4 Kozmoz genre: gaming dubstep added
# 2024-10-11 15:27:13,938 - INFO - 4jwHh8156lpD0ifm9bUCz4 Kozmoz genre: tearout added
# 2024-10-11 15:27:13,958 - INFO - Track: 7bvMExolp5KSmmYFhfbWjr Death is Real added
# 2024-10-11 15:27:13,972 - INFO - Updated audio features for 7bvMExolp5KSmmYFhfbWjr Death is Real
# 2024-10-11 15:27:13,988 - INFO - Track: 7bvjehr9hz2Xz9ZJZ1QzgB Revelation II added
# 2024-10-11 15:27:13,995 - INFO - Updated audio features for 7bvjehr9hz2Xz9ZJZ1QzgB Revelation II
# 2024-10-11 15:27:14,004 - INFO - Track: 7bxBo2l2lncW6UEIvaptoM Coagulate - Love & Light Remix added
# 2024-10-11 15:27:14,012 - INFO - Updated audio features for 7bxBo2l2lncW6UEIvaptoM Coagulate - Love & Light Remix
# 2024-10-11 15:27:14,013 - INFO - About to make an album call
# 2024-10-11 15:27:19,116 - INFO - Album: Postwavefuturecore Remixed added
# 2024-10-11 15:27:19,116 - INFO - Track: 7bywjHOc0wSjGGbj04XbVi LUNA added
# 2024-10-11 15:27:19,132 - INFO - Updated audio features for 7bywjHOc0wSjGGbj04XbVi LUNA
# 2024-10-11 15:27:19,132 - INFO - About to make an album call
